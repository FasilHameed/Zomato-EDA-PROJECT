# %% [markdown]
# <div align="center">
#   <h1><span style="color: blue;">Z</span><span style="color: red;">o</span><span style="color: green;">m</span><span style="color: yellow;">a</span><span style="color: orange;">t</span><span style="color: purple;">o</span> <span style="color: teal;">Exploratory</span> <span style="color: pink;">Data</span> <span style="color: cyan;">Analysis</span></h1>
#   <img src="https://mc.webpcache.epapr.in/discover.php?in=https://mcmscache.epapr.in/post_images/website_350/post_21404986/full.jpg" alt="Zomato Banner">
# </div>

# %% [markdown]
# #### `Importing Librabires Required`

# %%
# importing Pandas
import pandas as pd
# Import numpy
import numpy as np
# import set_matplotlib
import matplotlib.pyplot as plt
# import seaborn
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### `Data Loading`

# %%
#Restraunt Data
# import Data
df=pd.read_csv("Zomatodataset\zomato.csv",encoding="latin-1")
# check ist 5 rows
df.head(5).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_e7d38_row0_col0 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_e7d38_row0_col2, #T_e7d38_row0_col10, #T_e7d38_row0_col16, #T_e7d38_row1_col2, #T_e7d38_row1_col7, #T_e7d38_row1_col8, #T_e7d38_row1_col16, #T_e7d38_row2_col0, #T_e7d38_row2_col2, #T_e7d38_row2_col17, #T_e7d38_row3_col2, #T_e7d38_row4_col2, #T_e7d38_row4_col20 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e7d38_row0_col7 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_e7d38_row0_col8 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_e7d38_row0_col17, #T_e7d38_row4_col17 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_e7d38_row0_col20 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_e7d38_row1_col0 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_e7d38_row1_col10 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_e7d38_row1_col17 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_e7d38_row1_col20, #T_e7d38_row2_col10, #T_e7d38_row2_col16, #T_e7d38_row3_col0, #T_e7d38_row3_col8, #T_e7d38_row3_col16, #T_e7d38_row3_col17, #T_e7d38_row4_col7, #T_e7d38_row4_col16 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e7d38_row2_col7 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_e7d38_row2_col8 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_e7d38_row2_col20 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_e7d38_row3_col7 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_e7d38_row3_col10, #T_e7d38_row4_col10 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_e7d38_row3_col20 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_e7d38_row4_col0 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_e7d38_row4_col8 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7d38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7d38_level0_col0" class="col_heading level0 col0" >Restaurant ID</th>
#       <th id="T_e7d38_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_e7d38_level0_col2" class="col_heading level0 col2" >Country Code</th>
#       <th id="T_e7d38_level0_col3" class="col_heading level0 col3" >City</th>
#       <th id="T_e7d38_level0_col4" class="col_heading level0 col4" >Address</th>
#       <th id="T_e7d38_level0_col5" class="col_heading level0 col5" >Locality</th>
#       <th id="T_e7d38_level0_col6" class="col_heading level0 col6" >Locality Verbose</th>
#       <th id="T_e7d38_level0_col7" class="col_heading level0 col7" >Longitude</th>
#       <th id="T_e7d38_level0_col8" class="col_heading level0 col8" >Latitude</th>
#       <th id="T_e7d38_level0_col9" class="col_heading level0 col9" >Cuisines</th>
#       <th id="T_e7d38_level0_col10" class="col_heading level0 col10" >Average Cost for two</th>
#       <th id="T_e7d38_level0_col11" class="col_heading level0 col11" >Currency</th>
#       <th id="T_e7d38_level0_col12" class="col_heading level0 col12" >Has Table booking</th>
#       <th id="T_e7d38_level0_col13" class="col_heading level0 col13" >Has Online delivery</th>
#       <th id="T_e7d38_level0_col14" class="col_heading level0 col14" >Is delivering now</th>
#       <th id="T_e7d38_level0_col15" class="col_heading level0 col15" >Switch to order menu</th>
#       <th id="T_e7d38_level0_col16" class="col_heading level0 col16" >Price range</th>
#       <th id="T_e7d38_level0_col17" class="col_heading level0 col17" >Aggregate rating</th>
#       <th id="T_e7d38_level0_col18" class="col_heading level0 col18" >Rating color</th>
#       <th id="T_e7d38_level0_col19" class="col_heading level0 col19" >Rating text</th>
#       <th id="T_e7d38_level0_col20" class="col_heading level0 col20" >Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7d38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7d38_row0_col0" class="data row0 col0" >6317637</td>
#       <td id="T_e7d38_row0_col1" class="data row0 col1" >Le Petit Souffle</td>
#       <td id="T_e7d38_row0_col2" class="data row0 col2" >162</td>
#       <td id="T_e7d38_row0_col3" class="data row0 col3" >Makati City</td>
#       <td id="T_e7d38_row0_col4" class="data row0 col4" >Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City</td>
#       <td id="T_e7d38_row0_col5" class="data row0 col5" >Century City Mall, Poblacion, Makati City</td>
#       <td id="T_e7d38_row0_col6" class="data row0 col6" >Century City Mall, Poblacion, Makati City, Makati City</td>
#       <td id="T_e7d38_row0_col7" class="data row0 col7" >121.027535</td>
#       <td id="T_e7d38_row0_col8" class="data row0 col8" >14.565443</td>
#       <td id="T_e7d38_row0_col9" class="data row0 col9" >French, Japanese, Desserts</td>
#       <td id="T_e7d38_row0_col10" class="data row0 col10" >1100</td>
#       <td id="T_e7d38_row0_col11" class="data row0 col11" >Botswana Pula(P)</td>
#       <td id="T_e7d38_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_e7d38_row0_col13" class="data row0 col13" >No</td>
#       <td id="T_e7d38_row0_col14" class="data row0 col14" >No</td>
#       <td id="T_e7d38_row0_col15" class="data row0 col15" >No</td>
#       <td id="T_e7d38_row0_col16" class="data row0 col16" >3</td>
#       <td id="T_e7d38_row0_col17" class="data row0 col17" >4.800000</td>
#       <td id="T_e7d38_row0_col18" class="data row0 col18" >Dark Green</td>
#       <td id="T_e7d38_row0_col19" class="data row0 col19" >Excellent</td>
#       <td id="T_e7d38_row0_col20" class="data row0 col20" >314</td>
#     </tr>
#     <tr>
#       <th id="T_e7d38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7d38_row1_col0" class="data row1 col0" >6304287</td>
#       <td id="T_e7d38_row1_col1" class="data row1 col1" >Izakaya Kikufuji</td>
#       <td id="T_e7d38_row1_col2" class="data row1 col2" >162</td>
#       <td id="T_e7d38_row1_col3" class="data row1 col3" >Makati City</td>
#       <td id="T_e7d38_row1_col4" class="data row1 col4" >Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City</td>
#       <td id="T_e7d38_row1_col5" class="data row1 col5" >Little Tokyo, Legaspi Village, Makati City</td>
#       <td id="T_e7d38_row1_col6" class="data row1 col6" >Little Tokyo, Legaspi Village, Makati City, Makati City</td>
#       <td id="T_e7d38_row1_col7" class="data row1 col7" >121.014101</td>
#       <td id="T_e7d38_row1_col8" class="data row1 col8" >14.553708</td>
#       <td id="T_e7d38_row1_col9" class="data row1 col9" >Japanese</td>
#       <td id="T_e7d38_row1_col10" class="data row1 col10" >1200</td>
#       <td id="T_e7d38_row1_col11" class="data row1 col11" >Botswana Pula(P)</td>
#       <td id="T_e7d38_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_e7d38_row1_col13" class="data row1 col13" >No</td>
#       <td id="T_e7d38_row1_col14" class="data row1 col14" >No</td>
#       <td id="T_e7d38_row1_col15" class="data row1 col15" >No</td>
#       <td id="T_e7d38_row1_col16" class="data row1 col16" >3</td>
#       <td id="T_e7d38_row1_col17" class="data row1 col17" >4.500000</td>
#       <td id="T_e7d38_row1_col18" class="data row1 col18" >Dark Green</td>
#       <td id="T_e7d38_row1_col19" class="data row1 col19" >Excellent</td>
#       <td id="T_e7d38_row1_col20" class="data row1 col20" >591</td>
#     </tr>
#     <tr>
#       <th id="T_e7d38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7d38_row2_col0" class="data row2 col0" >6300002</td>
#       <td id="T_e7d38_row2_col1" class="data row2 col1" >Heat - Edsa Shangri-La</td>
#       <td id="T_e7d38_row2_col2" class="data row2 col2" >162</td>
#       <td id="T_e7d38_row2_col3" class="data row2 col3" >Mandaluyong City</td>
#       <td id="T_e7d38_row2_col4" class="data row2 col4" >Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City</td>
#       <td id="T_e7d38_row2_col5" class="data row2 col5" >Edsa Shangri-La, Ortigas, Mandaluyong City</td>
#       <td id="T_e7d38_row2_col6" class="data row2 col6" >Edsa Shangri-La, Ortigas, Mandaluyong City, Mandaluyong City</td>
#       <td id="T_e7d38_row2_col7" class="data row2 col7" >121.056831</td>
#       <td id="T_e7d38_

# %%
# country Data
df_country=pd.read_excel('Zomatodataset\Country-Code.xlsx')
df_country.head(4)
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada

# %% [markdown]
# ### `Knowing Your Data`

# %%
def check_data(df):
    print(f"Basic Info about the Dataset",{'df'})
    print("Data Types for Each Column".center(82, '~'))
    print("<>".center(82, '~'))
    print(df.info())
    print("The sum Null Values for Each column In the Data Set Are".center(82, '~'))
    print("<>".center(82, '~'))
    print(df.isnull().sum())
    print("The names Of the Columns In the Data Set are".center(82, '~'))
    print("<>".center(82, '~'))
    print(df.columns)
    print("The Shape of the columns is".center(82, '~'))
    print("<>".center(82, '~'))
    print(f"the number of rows in data set are" ,{df.shape[0]},"and The Number of Coluns is",{df.shape[1]} )
    print("5 point Summary".center(82, '~'))
    print(df.describe())
check_data(df)
# Out:
# Basic Info about the Dataset {'df'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~Data Types for Each Column~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), object(13)
# memory usage: 1.5+ MB
# None
# ~~~~~~~~~~~~~The sum Null Values for Each column In the Data Set Are~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~The names Of the Columns In the Data Set are~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~The Shape of the columns is~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# the number of rows in data set are {9551} and The Number of Coluns is {21}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~5 point Summary~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
# country Data
check_data(df_country)
# Out:
# Basic Info about the Dataset {'df'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~Data Types for Each Column~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 372.0+ bytes
# None
# ~~~~~~~~~~~~~The sum Null Values for Each column In the Data Set Are~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Country Code    0
# Country         0
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~The names Of the Columns In the Data Set are~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Index(['Country Code', 'Country'], dtype='object')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~The Shape of the columns is~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# the number of rows in data set are {15} and The Number of Coluns is {2}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~5 point Summary~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        Country Code
# count     15.000000
# mean     137.933333
# std       80.009345
# min        1.000000
# 25%       65.500000
# 50%      166.000000
# 75%      199.500000
# max      216.000000

# %% [markdown]
# `Know Your Data better`

# %%
# Checking For columns with Missing Values 
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
# Checking For Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check Column Names
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Merging The Data Sets
final_df=pd.merge(df,df_country,on='Country Code',how='left')

# %%
# final dataset 
final_df.head(3).style.background_gradient('Reds')
# Out:
# <style type="text/css">
# #T_f16cc_row0_col0, #T_f16cc_row0_col17, #T_f16cc_row1_col20, #T_f16cc_row2_col7, #T_f16cc_row2_col8, #T_f16cc_row2_col10, #T_f16cc_row2_col16 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f16cc_row0_col2, #T_f16cc_row0_col10, #T_f16cc_row0_col16, #T_f16cc_row1_col2, #T_f16cc_row1_col7, #T_f16cc_row1_col8, #T_f16cc_row1_col16, #T_f16cc_row2_col0, #T_f16cc_row2_col2, #T_f16cc_row2_col17, #T_f16cc_row2_col20 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f16cc_row0_col7 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_f16cc_row0_col8 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_f16cc_row0_col20 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_f16cc_row1_col0 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_f16cc_row1_col10 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_f16cc_row1_col17 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# </style>
# <table id="T_f16cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f16cc_level0_col0" class="col_heading level0 col0" >Restaurant ID</th>
#       <th id="T_f16cc_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_f16cc_level0_col2" class="col_heading level0 col2" >Country Code</th>
#       <th id="T_f16cc_level0_col3" class="col_heading level0 col3" >City</th>
#       <th id="T_f16cc_level0_col4" class="col_heading level0 col4" >Address</th>
#       <th id="T_f16cc_level0_col5" class="col_heading level0 col5" >Locality</th>
#       <th id="T_f16cc_level0_col6" class="col_heading level0 col6" >Locality Verbose</th>
#       <th id="T_f16cc_level0_col7" class="col_heading level0 col7" >Longitude</th>
#       <th id="T_f16cc_level0_col8" class="col_heading level0 col8" >Latitude</th>
#       <th id="T_f16cc_level0_col9" class="col_heading level0 col9" >Cuisines</th>
#       <th id="T_f16cc_level0_col10" class="col_heading level0 col10" >Average Cost for two</th>
#       <th id="T_f16cc_level0_col11" class="col_heading level0 col11" >Currency</th>
#       <th id="T_f16cc_level0_col12" class="col_heading level0 col12" >Has Table booking</th>
#       <th id="T_f16cc_level0_col13" class="col_heading level0 col13" >Has Online delivery</th>
#       <th id="T_f16cc_level0_col14" class="col_heading level0 col14" >Is delivering now</th>
#       <th id="T_f16cc_level0_col15" class="col_heading level0 col15" >Switch to order menu</th>
#       <th id="T_f16cc_level0_col16" class="col_heading level0 col16" >Price range</th>
#       <th id="T_f16cc_level0_col17" class="col_heading level0 col17" >Aggregate rating</th>
#       <th id="T_f16cc_level0_col18" class="col_heading level0 col18" >Rating color</th>
#       <th id="T_f16cc_level0_col19" class="col_heading level0 col19" >Rating text</th>
#       <th id="T_f16cc_level0_col20" class="col_heading level0 col20" >Votes</th>
#       <th id="T_f16cc_level0_col21" class="col_heading level0 col21" >Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f16cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f16cc_row0_col0" class="data row0 col0" >6317637</td>
#       <td id="T_f16cc_row0_col1" class="data row0 col1" >Le Petit Souffle</td>
#       <td id="T_f16cc_row0_col2" class="data row0 col2" >162</td>
#       <td id="T_f16cc_row0_col3" class="data row0 col3" >Makati City</td>
#       <td id="T_f16cc_row0_col4" class="data row0 col4" >Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City</td>
#       <td id="T_f16cc_row0_col5" class="data row0 col5" >Century City Mall, Poblacion, Makati City</td>
#       <td id="T_f16cc_row0_col6" class="data row0 col6" >Century City Mall, Poblacion, Makati City, Makati City</td>
#       <td id="T_f16cc_row0_col7" class="data row0 col7" >121.027535</td>
#       <td id="T_f16cc_row0_col8" class="data row0 col8" >14.565443</td>
#       <td id="T_f16cc_row0_col9" class="data row0 col9" >French, Japanese, Desserts</td>
#       <td id="T_f16cc_row0_col10" class="data row0 col10" >1100</td>
#       <td id="T_f16cc_row0_col11" class="data row0 col11" >Botswana Pula(P)</td>
#       <td id="T_f16cc_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_f16cc_row0_col13" class="data row0 col13" >No</td>
#       <td id="T_f16cc_row0_col14" class="data row0 col14" >No</td>
#       <td id="T_f16cc_row0_col15" class="data row0 col15" >No</td>
#       <td id="T_f16cc_row0_col16" class="data row0 col16" >3</td>
#       <td id="T_f16cc_row0_col17" class="data row0 col17" >4.800000</td>
#       <td id="T_f16cc_row0_col18" class="data row0 col18" >Dark Green</td>
#       <td id="T_f16cc_row0_col19" class="data row0 col19" >Excellent</td>
#       <td id="T_f16cc_row0_col20" class="data row0 col20" >314</td>
#       <td id="T_f16cc_row0_col21" class="data row0 col21" >Phillipines</td>
#     </tr>
#     <tr>
#       <th id="T_f16cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f16cc_row1_col0" class="data row1 col0" >6304287</td>
#       <td id="T_f16cc_row1_col1" class="data row1 col1" >Izakaya Kikufuji</td>
#       <td id="T_f16cc_row1_col2" class="data row1 col2" >162</td>
#       <td id="T_f16cc_row1_col3" class="data row1 col3" >Makati City</td>
#       <td id="T_f16cc_row1_col4" class="data row1 col4" >Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City</td>
#       <td id="T_f16cc_row1_col5" class="data row1 col5" >Little Tokyo, Legaspi Village, Makati City</td>
#       <td id="T_f16cc_row1_col6" class="data row1 col6" >Little Tokyo, Legaspi Village, Makati City, Makati City</td>
#       <td id="T_f16cc_row1_col7" class="data row1 col7" >121.014101</td>
#       <td id="T_f16cc_row1_col8" class="data row1 col8" >14.553708</td>
#       <td id="T_f16cc_row1_col9" class="data row1 col9" >Japanese</td>
#       <td id="T_f16cc_row1_col10" class="data row1 col10" >1200</td>
#       <td id="T_f16cc_row1_col11" class="data row1 col11" >Botswana Pula(P)</td>
#       <td id="T_f16cc_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_f16cc_row1_col13" class="data row1 col13" >No</td>
#       <td id="T_f16cc_row1_col14" class="data row1 col14" >No</td>
#       <td id="T_f16cc_row1_col15" class="data row1 col15" >No</td>
#       <td id="T_f16cc_row1_col16" class="data row1 col16" >3</td>
#       <td id="T_f16cc_row1_col17" class="data row1 col17" >4.500000</td>
#       <td id="T_f16cc_row1_col18" class="data row1 col18" >Dark Green</td>
#       <td id="T_f16cc_row1_col19" class="data row1 col19" >Excellent</td>
#       <td id="T_f16cc_row1_col20" class="data row1 col20" >591</td>
#       <td id="T_f16cc_row1_col21" class="data row1 col21" >Phillipines</td>
#     </tr>
#     <tr>
#       <th id="T_f16cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f16cc_row2_col0" class="data row2 col0" >6300002</td>
#       <td id="T_f16cc_row2_col1" class="data row2 col1" >Heat - Edsa Shangri-La</td>
#       <td id="T_f16cc_row2_col2" class="data row2 col2" >162</td>
#       <td id="T_f16cc_row2_col3" class="data row2 col3" >Mandaluyong City</td>
#       <td id="T_f16cc_row2_col4" class="data row2 col4" >Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City</td>
#       <td id="T_f16cc_row2_col5" class="data row2 col5" >Edsa Shangri-La, Ortigas, Mandaluyong City</td>
#       <td id="T_f16cc_row2_col6" class="data row2 col6" >Edsa Shangri-La, Ortigas, Mandaluyong City, Mandaluyong City</td>
#       <td id="T_f16cc_row2_col7" class="data row2 col7" >121.056831</td>
#       <td id="T_f16cc_row2_col8" class="data row2 col8" >14.581404</td>
#       <td id="T_f16cc_row2_col9" class="data row2 col9" >Seafood, Asian, Filipino, Indian</td>
#       <td id="T_f16cc_row2_col10" class="data row2 col10" >4000</td>
#       <td id="T_f16cc_row2_col11" class="data row2 col11" >Botswana Pula(P)</td>
#       <td id="T_f16cc_row2_col12" class="data row2 col12" >Yes</td>
#       <td id="T_f16cc_row2_col13" class="data row2 col13" >No</td>
#       <td id="T_f16cc_row2_col14" class="data row2 col14" >No</td>
#       <td id="T_f16cc_row2_col15" class="data row2 col15" >No</td>
#       <td id="T_f16cc_row2_co

# %%
# check basic info at onece for final Data Set
check_data(final_df)
# Out:
# Basic Info about the Dataset {'df'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~Data Types for Each Column~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
#  21  Country               9551 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.6+ MB
# None
# ~~~~~~~~~~~~~The sum Null Values for Each column In the Data Set Are~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~The names Of the Columns In the Data Set are~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~The Shape of the columns is~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~<>~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# the number of rows in data set are {9551} and The Number of Coluns is {22}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~5 point Summary~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
# check Each Thing manually
# check dtypes
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# check Column names
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# column wise value count
final_df.Country.value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
# `Deriving few Features`
# extracting country names and there Respective Values 
country_names=final_df.Country.value_counts().index
country_values=final_df.Country.value_counts().values

# %%
# plot pie chart
plt.pie(country_values[:3],labels=country_names[:3],autopct='%1.2f%%',explode=[0.5,0.2,0.3])
# Out:
# ([<matplotlib.patches.Wedge at 0x2550c04f650>,
#   <matplotlib.patches.Wedge at 0x2550c1d8f10>,
#   <matplotlib.patches.Wedge at 0x2550c1daa90>],
#  [Text(-1.5752353019566696, 0.2804170884048978, 'India'),
#   Text(1.273151118718057, -0.2628425934032753, 'United States'),
#   Text(1.3994737468502043, -0.03838270283669911, 'United Kingdom')],
#  [Text(-1.0829742700952103, 0.19278674827836723, '94.39%'),
#   Text(0.7834776115188044, -0.16174928824816942, '4.73%'),
#   Text(0.8996616944037028, -0.02467459468073514, '0.87%')])

# %% [markdown]
# max transactions from india

# %%
# grouping rating related Text
rating=final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
# Ratings 
rating.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_2fd5e_row0_col0, #T_2fd5e_row1_col3, #T_2fd5e_row2_col3, #T_2fd5e_row3_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2fd5e_row0_col3, #T_2fd5e_row32_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2fd5e_row1_col0 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_2fd5e_row2_col0 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_2fd5e_row3_col0 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_2fd5e_row4_col0 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_2fd5e_row4_col3, #T_2fd5e_row31_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_2fd5e_row5_col0 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_2fd5e_row5_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_2fd5e_row6_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_2fd5e_row6_col3 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_2fd5e_row7_col0 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_2fd5e_row7_col3, #T_2fd5e_row28_col3 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_2fd5e_row8_col0 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_2fd5e_row8_col3 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_2fd5e_row9_col0 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_2fd5e_row9_col3 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_2fd5e_row10_col0 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_2fd5e_row10_col3 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_2fd5e_row11_col0 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_2fd5e_row11_col3 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_2fd5e_row12_col0 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_2fd5e_row12_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_2fd5e_row13_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_2fd5e_row13_col3 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_2fd5e_row14_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_2fd5e_row14_col3 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_2fd5e_row15_col0 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_2fd5e_row15_col3 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_2fd5e_row16_col0 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_2fd5e_row16_col3, #T_2fd5e_row18_col3 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_2fd5e_row17_col0 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_2fd5e_row17_col3 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_2fd5e_row18_col0 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_2fd5e_row19_col0 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_2fd5e_row19_col3 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_2fd5e_row20_col0 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_2fd5e_row20_col3 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_2fd5e_row21_col0 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_2fd5e_row21_col3 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_2fd5e_row22_col0 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_2fd5e_row22_col3 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_2fd5e_row23_col0 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_2fd5e_row23_col3 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_2fd5e_row24_col0 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_2fd5e_row24_col3 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_2fd5e_row25_col0 {
#   background-color: #05712f;
#   color: #f1f1f1;
# }
# #T_2fd5e_row25_col3 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_2fd5e_row26_col0 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_2fd5e_row26_col3 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_2fd5e_row27_col0 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_2fd5e_row27_col3 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_2fd5e_row28_col0 {
#   background-color: #005e26;
#   color: #f1f1f1;
# }
# #T_2fd5e_row29_col0 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_2fd5e_row29_col3 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_2fd5e_row30_col0 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_2fd5e_row30_col3 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_2fd5e_row31_col0 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_2fd5e_row32_col3 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# </style>
# <table id="T_2fd5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fd5e_level0_col0" class="col_heading level0 col0" >Aggregate rating</th>
#       <th id="T_2fd5e_level0_col1" class="col_heading level0 col1" >Rating color</th>
#       <th id="T_2fd5e_level0_col2" class="col_heading level0 col2" >Rating text</th>
#       <th id="T_2fd5e_level0_col3" class="col_heading level0 col3" >Rating count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fd5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fd5e_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_2fd5e_row0_col1" class="data row0 col1" >White</td>
#       <td id="T_2fd5e_row0_col2" class="data row0 col2" >Not rated</td>
#       <td id="T_2fd5e_row0_col3" class="data row0 col3" >2148</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2fd5e_row1_col0" class="data row1 col0" >1.800000</td>
#       <td id="T_2fd5e_row1_col1" class="data row1 col1" >Red</td>
#       <td id="T_2fd5e_row1_col2" class="data row1 col2" >Poor</td>
#       <td id="T_2fd5e_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2fd5e_row2_col0" class="data row2 col0" >1.900000</td>
#       <td id="T_2fd5e_row2_col1" class="data row2 col1" >Red</td>
#       <td id="T_2fd5e_row2_col2" class="data row2 col2" >Poor</td>
#       <td id="T_2fd5e_row2_col3" class="data row2 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2fd5e_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_2fd5e_row3_col1" class="data row3 col1" >Red</td>
#       <td id="T_2fd5e_row3_col2" class="data row3 col2" >Poor</td>
#       <td id="T_2fd5e_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2fd5e_row4_col0" class="data row4 col0" >2.100000</td>
#       <td id="T_2fd5e_row4_col1" class="data row4 col1" >Red</td>
#       <td id="T_2fd5e_row4_col2" class="data row4 col2" >Poor</td>
#       <td id="T_2fd5e_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2fd5e_row5_col0" class="data row5 col0" >2.200000</td>
#       <td id="T_2fd5e_row5_col1" class="data row5 col1" >Red</td>
#       <td id="T_2fd5e_row5_col2" class="data row5 col2" >Poor</td>
#       <td id="T_2fd5e_row5_col3" class="data row5 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2fd5e_row6_col0" class="data row6 col0" >2.300000</td>
#       <td id="T_2fd5e_row6_col1" class="data row6 col1" >Red</td>
#       <td id="T_2fd5e_row6_col2" class="data row6 col2" >Poor</td>
#       <td id="T_2fd5e_row6_col3" class="data row6 col3" >47</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2fd5e_row7_col0" class="data row7 col0" >2.400000</td>
#       <td id="T_2fd5e_row7_col1" class="data row7 col1" >Red</td>
#       <td id="T_2fd5e_row7_col2" class="data row7 col2" >Poor</td>
#       <td id="T_2fd5e_row7_col3" class="data row7 col3" >87</td>
#     </tr>
#     <tr>
#       <th id="T_2fd5e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2fd5e_row8_col0" class="data row8 col0" >2.500000</td>
#       <td id="T_2fd5e_row8_col1" class="data row8 col1" >Orange</td>
#       <td id="T_2fd5e_row8_col2" class="data row8 col2"

# %% [markdown]
# observation
# - between 4.5 -4.9 = excelent
# - 4.0 -4.4 = very good
# - 3.5 -3.9 = good
# - 2.5-2.9 - average
# - below 2.5 - poor

# %%
# Histogram Of Rating
plt.figure(figsize=(12,8))
sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',palette=['white','red','orange','yellow','green'],data=rating)
plt.ylabel('Number of Ratings')
plt.xlabel("rating ")
# Out:
# C:\Users\faisa\AppData\Local\Temp\ipykernel_19392\3377048741.py:3: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',palette=['white','red','orange','yellow','green'],data=rating)
# Text(0.5, 0, 'rating ')

# %% [markdown]
# observation
# - max rating between 2.5 -4.4

# %%
# count plot
sns.countplot(x='Rating color',data=rating,palette=['white','red','orange','yellow','green'])
# Out:
# C:\Users\faisa\AppData\Local\Temp\ipykernel_19392\2972311763.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color',data=rating,palette=['white','red','orange','yellow','green'])
# C:\Users\faisa\AppData\Local\Temp\ipykernel_19392\2972311763.py:2: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='Rating color',data=rating,palette=['white','red','orange','yellow','green'])
# <Axes: xlabel='Rating color', ylabel='count'>
